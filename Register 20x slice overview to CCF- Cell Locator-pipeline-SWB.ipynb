# %%
import os 
import glob
import json
import numpy as np
import pandas as pd
import SimpleITK as sitk
import psycopg2
import matplotlib.pyplot as plt
from numpy.linalg import inv
import requests
import shutil
import re

import sys
sys.path.append(r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\ccf_slice_registration')
from ccf_slice_registration_functions import *

sys.path.append(r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\lims_queries\cell_soma_structure_and_coords')
from soma_and_fiducial_pins import *

# %matplotlib inline

# %% [markdown]
# Inputs

# %%
pins_path = get_soma_and_fiducial_pins()
pins = pd.read_csv(pins_path)
# Out:
# {'slide_specimen_id': 1069147202, 'specimen_name': 'Esr2-IRES2-Cre;Ai14-557045.04.09a'}
# WARNING: more than one control point, using the first
# {'slide_specimen_id': 1069147202, 'specimen_name': 'Esr2-IRES2-Cre;Ai14-557045.04.09b'}
# WARNING: more than one control point, using the first
# {'slide_specimen_id': 1069147202, 'specimen_name': 'Esr2-IRES2-Cre;Ai14-557045.04.09c'}
# WARNING: more than one control point, using the first
# {'slide_specimen_id': 1102538034, 'specimen_name': 'Sst-IRES-Cre;Ai14-577302.07.04a', 'x': 4149.999999999999, 'y': 6388.183016393443, 'z': 8525.720459016393, 'structure_id': 0}
# WARNING: not a valid structure - skipping
# {'slide_specimen_id': 1068927614, 'specimen_name': 'Esr2-IRES2-Cre;Ai14-557044.05.09.03.01'}
# WARNING: more than one control point, using the first
# {'slide_specimen_id': 1208614358, 'specimen_name': 'Curve'}
# WARNING: control point list empty, skipping
# {'slide_specimen_id': 1262448162, 'specimen_name': 'Sst-IRES-Cre;Ai14-670419.09.03.02'}
# WARNING: more than one control point, using the first
# {'slide_specimen_id': 1266114320, 'specimen_name': 'Gad2-IRES-Cre;Ai14-670842.06.02.01'}
# WARNING: more than one control point, using the first
# {'slide_specimen_id': 1078776834, 'specimen_name': ' Htr3a-Cre_NO152;Ai14-563514.10.09.03'}
# WARNING: more than one control point, using the first

# %%
pins['specimen_name'] = pins['specimen_name'].str.strip() #strip any erroneous white space from the start and end fo specimen names

# %%
#pins contains fiducail pins (specimen name ends in a letter) and soma pins (specimen name ends in a number)
#break up pins into fiducial vs soma pin dataframes
fiducials_dict = {}
somas_dict = {}
for i, p in pins.iterrows():
    last_pin_char = p['specimen_name'][-1]
    if last_pin_char.isalpha(): fiducials_dict[i] = p #the last char of the pin name is a letter, so this is a fiducial (not a soma) pin 
    else: somas_dict[i] = p #the last char of the pin name is a number, so this is a soma (not a fiducial) pin

# %%
somas = pd.DataFrame.from_dict(somas_dict, orient='index').reset_index().drop(['index'], axis=1)
somas
# Out:
#       slide_specimen_id            specimen_name            x            y
# 0            1254192732  C57BL6J-667412.13.10.01  6725.000000  3807.984131  \
# 1            1254192732  C57BL6J-667412.13.10.02  6725.000000  3685.511719
# 2            1254192732  C57BL6J-667412.13.10.03  6725.000000  3607.036133
# 3            1189282403  C57BL6J-634112.05.01.01  8846.905344  1215.824000
# 4            1189282403  C57BL6J-634112.05.01.02  8698.307617  1624.090698
# ...                 ...                      ...          ...          ...
# 2925         1170367254  C57BL6J-622939.07.04.02  4331.213867  4061.798584
# 2926         1164113385  C57BL6J-618127.06.03.01  4275.000000  6365.933594
# 2927         1164113385  C57BL6J-618127.06.03.02  4275.000000  3978.592529
# 2928         1164113385  C57BL6J-618127.06.03.03  4275.000000  4124.779297
# 2929         1164113385  C57BL6J-618127.06.03.04  4275.000000  4512.876953
#
#                 z  structure_id structure_acronym
# 0     6180.958496           362                MD
# 1     6276.875000           362                MD
# 2     6302.043457           362                MD
# 3     2322.970703           821           VISp2/3
# 4     2576.191895           778             VISp5
# ...           ...           ...               ...
# 2925  6512.082520           672                CP
# 2926  4770.908691            56               ACB
# 2927  4848.456055           672                CP
# 2928  3536.724121           672                CP
# 2929  3494.421631           672                CP
#
# [2930 rows x 7 columns]

# %%
fiducials = pd.DataFrame.from_dict(fiducials_dict, orient='index').reset_index().drop(['index'], axis=1)
fiducials
# Out:
#      slide_specimen_id                         specimen_name            x
# 0           1092005159  Glt25d2-Cre_NF107;Ai14-570372.07.09c  6975.000000  \
# 1           1092005159  Glt25d2-Cre_NF107;Ai14-570372.07.09b  6975.000000
# 2           1092005159  Glt25d2-Cre_NF107;Ai14-570372.07.09a  6975.000000
# 3           1110990523       Sst-IRES-Cre;Ai14-581875.06.04a  4450.000000
# 4           1110990523       Sst-IRES-Cre;Ai14-581875.06.04b  4450.000000
# ..                 ...                                   ...          ...
# 401         1170367254                 C57BL6J-622939.07.04b  4532.975098
# 402         1170367254                 C57BL6J-622939.07.04c  4448.302525
# 403         1164113385                 C57BL6J-618127.06.03a  4275.000000
# 404         1164113385                 C57BL6J-618127.06.03b  4275.000000
# 405         1164113385                 C57BL6J-618127.06.03c  4275.000000
#
#                y            z  structure_id structure_acronym
# 0    5882.571390  8955.783924           303              BLAa
# 1    3045.212654  8379.161362           603                fi
# 2    5294.686747  6272.187891           690               mtt
# 3    6401.548780  8550.109756           665               lot
# 4    5408.768293  6864.256098           900               aco
# ..           ...          ...           ...               ...
# 401  6367.930664  8660.227539           665               lot
# 402  5400.128877  6849.207031           900               aco
# 403  3468.452607  4859.073959            98               SEZ
# 404  6361.486503  2930.384694           665               lot
# 405  5405.752091  4463.003842           900               aco
#
# [406 rows x 7 columns]

# %%
slices = fiducials.slide_specimen_id.unique() #get the slices that have fiducials
len(slices)
# Out:
# 132

# %%
# #run julia's cells that failed the first time
# missing_cells = pd.read_csv(r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\datasets\mouse_subcortical_msn_d1\10132023_ccf_reg\MSN_D1_Dataset_Sep_2023_failedCCFReg.csv')
# missing_cells

# %%
# missing_cell_list = missing_cells['Specimen Name'].values
# somas = somas[somas['specimen_name'].isin(missing_cell_list)]
# somas

# %%
# slices = somas.slide_specimen_id.unique()
# slices

# %%
# slices = [1113439943]

# %%
# fiducials[fiducials['slide_specimen_id'].isin(slices)].sort_values(by='slide_specimen_id')

# %%
# somas[somas['slide_specimen_id'].isin(slices)].sort_values(by='slide_specimen_id')

# %%
out = r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\ccf_slice_registration\ccf_reg_output_20231031' #folder to save slide transforms

# %%
# # cells = pd.read_csv(r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\ccf_slice_registration\fiducals.csv', encoding='windows-1252') #slides with fiducials
# cells = pd.read_csv(r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\ccf_slice_registration\ccf_reg_input\cells_with_fiducials_20230825.csv') #slides with fiducials
# # # cells = cells[cells['Fiducials drawn'] == 'complete + saved'] #get just cells with fiducials
# # slices = cells.slice_id.unique() #get the slices that have fiducials

# out = r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\ccf_slice_registration\ccf_reg_output' #folder to save slide transforms

# %%
# # cells = pd.read_csv(r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\ccf_slice_registration\fiducals.csv', encoding='windows-1252') #slides with fiducials
# # cells = pd.read_csv(r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\ccf_slice_registration\ccf_reg_input\cells_with_fiducials_20230825.csv') #slides with fiducials
# cells = pd.read_csv(r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\datasets\mouse_subcortical_msn_d1\09122023_ccf_reg\MSN_D1_Dataset_Sep_2023_formatted.csv')
# # # cells = cells[cells['Fiducials drawn'] == 'complete + saved'] #get just cells with fiducials
# slices = cells.slice_id.unique() #get the slices that have fiducials

# out = r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\ccf_slice_registration\ccf_reg_output_msn_d1s' #folder to save slide transforms

# %% [markdown]
# Load CCF

# %%
# read in CCF (with fixed headers)
image_directory =  r'\\allen\programs\celltypes\workgroups\mousecelltypes\_UPENN_fMOST\mouse_ccf_fixed_headers_um\average_template'
ccf_file = os.path.join(image_directory, "average_template_10.nii.gz" )
ccf = sitk.ReadImage( ccf_file )

# %% [markdown]
# Transform slices to CCF

# %%
#loop through all slices, registering them to the ccf 
slices_with_issues = {}
for specimen_id in slices:
    specimen_id = int(specimen_id)
    # specimen_id = 1108154695 #a good ex

    #get slice name 
    specimen_name = get_name_by_id(specimen_id)
    print(specimen_name)

    try:

        #make folder to store transform for this slice 
        working_directory = os.path.join(out, specimen_name)
        if not os.path.exists(working_directory):
            os.mkdir(working_directory)

        # read in pinning tool output - virtual slice definition and cell ccf locations
        pinning_info = get_pinning(specimen_name)[4]

        # virtual_slice_to_ccf_transform: transform a 3D point (in micron) in the virtual slice to ccf (in micron)
        # ccf_to_virtual_slice_transform: transform a 3D point in ccf (in micron) to virtual slice (in micron)
        # (note: each point can have its own orientation - we are taking the first one only #TODO is this an issue? (swb))
        virtual_slice_to_ccf_transform = initialize_transform( pinning_info['markups'][0]['orientation'] )
        ccf_to_virtual_slice_transform = virtual_slice_to_ccf_transform.GetInverse()

        # write out the virtual_slice_to_ccf_transform
        file = os.path.join(working_directory, 'virtual_slice_to_ccf_transform.txt')
        sitk.WriteTransform( virtual_slice_to_ccf_transform, file )


        # generate a virtual slice from the transforms
        #   virtual_slice_3d is a 3D volume with a single z slice
        #   virtual_slice    is a 2D volume created by extracting out the single slice
        virtual_slice_size = [1250,1250,1] # 3D volume with one slice
        virtual_slice_spacing = ccf.GetSpacing()
        virtual_slice_3d = sitk.Resample(ccf, 
                                        virtual_slice_size, 
                                        virtual_slice_to_ccf_transform, 
                                        sitk.sitkLinear,
                                        [0,0,0], 
                                        virtual_slice_spacing, 
                                        [1,0,0,0,1,0,0,0,1], 
                                        0.0, 
                                        ccf.GetPixelID())#, False )


        virtual_slice = virtual_slice_3d[:,:,0] # 2D image version

        # read in the 2D overview image and associate metadata
        img_info = [list(get_20x_info(specimen_name))]

        odf = pd.DataFrame(img_info, columns = ['specimen_name', 'sub_image_id', 'width', 'height', 'resolution', 'treatment_id'])
        overview_info = odf.loc[0]
        sub_image = odf['sub_image_id'].values[0]
        get_20x_img(sub_image, specimen_name, working_directory)   
        file = os.path.join(working_directory, '{}_overview.jpg'.format(specimen_name))
        overview = sitk.ReadImage( file )
        overview_spacing = [overview_info['resolution'],overview_info['resolution']]
        overview.SetSpacing(overview_spacing)

        # downsample the 2D overview image
        downsampled_overview = sitk.BinShrink( sitk.VectorIndexSelectionCast(overview,0), [25,25])

        # write the downsampled overview to file
        file = os.path.join(working_directory,'downsampled_overview.nii.gz')
        sitk.WriteImage( downsampled_overview, file, True )

        # Read in drawn soma polygons to create matching landmarks set
        df = get_soma_polygons(specimen_id)

        # For each cell
        #  - compute cell soma from polyline in pixels
        #  - convert cell soma location to microns
        #  - join with cell soma location in CCF
        #  - compute cell soma location in virtual slice
        df['center_pixel'] = [compute_center_from_polyline(p) for p in df['poly_coords']]
        df['center_micron'] = [np.multiply(p,overview_spacing) for p in df['center_pixel']]

        jdict = {}
        for m in pinning_info['markups'] :
            jdict[m['name'].strip()] = m['markup']['controlPoints'][0]['position']
            
        df['ccf_coordinate'] = [jdict[p] for p in df['specimen_name']]
        df['virtual_slice_coordinate'] = [ ccf_to_virtual_slice_transform.TransformPoint(p)[:2] for p in df['ccf_coordinate'] ]
        #save df
        df.to_csv(os.path.join(working_directory, 'alignment_output.csv'), index=False)


        # for c in jdict.keys():
        #     print('|{}|'.format(c))

        lndmrks = get_landmark_ids(specimen_id)
        ldf = pd.DataFrame()
        for c in lndmrks:
            # print(c)
            this_lndmrk = get_landmark_location(c[0])
            ldf = pd.concat([ldf, this_lndmrk])
            
        ldf['center_pixel'] = [compute_center_from_polyline(p) for p in ldf['poly_coords']]
        ldf['overview_coordinate'] = [np.multiply(p,overview_spacing) for p in ldf['center_pixel']]

        ldf['ccf_coordinate'] = [jdict[p] for p in ldf['specimen_name']]
        ldf['virtual_slice_coordinate'] = [ ccf_to_virtual_slice_transform.TransformPoint(p)[:2] for p in ldf['ccf_coordinate'] ]

        if len(ldf) < 3:
            print('\tnot enough fiducials')
            # slices_with_issues[specimen_name] = 'not enough fiducials'
            continue

        # determine if slice was flipped, if so fix virtual to ccf transform 
        if slice_flipped(ldf):
            transform = virtual_slice_to_ccf_transform.GetParameters()
            transform = list(transform)
            idx = -1
            if pinning_info['referenceView'].lower() == 'sagittal': idx = 2 #flip coronal axis in PIL to LPS transform 
            if pinning_info['referenceView'].lower() == 'coronal': idx = 5 #flip saggital axis in RIA to LPS transform 
            if idx > -1: transform[idx] = transform[idx]*-1 #flip axis
            #TODO do I need to update one of the last three numbers in transform? 
            transform = tuple(transform)
            virtual_slice_to_ccf_transform.SetParameters(transform)

            # write out the virtual_slice_to_ccf_transform
            file = os.path.join(working_directory, 'virtual_slice_to_ccf_transform.txt')
            sitk.WriteTransform( virtual_slice_to_ccf_transform, file )

        # Concatentate landmarks (cell soma + additional) for registration
        # virtual slice (fixed) landmarks
        fixed_landmarks = [tuple(p) for p in df['virtual_slice_coordinate']]
        fixed_landmarks.extend([tuple(p) for p in ldf['virtual_slice_coordinate']] )

        # overview (moving) landmarks
        moving_landmarks = [tuple(p) for p in df['center_micron']]
        moving_landmarks.extend([tuple(p) for p in ldf['overview_coordinate']] )

        # virtual_slice_to_overview_transform: transform a 2D point (in microns) in the virtual slice to overview image (in microns)
        # overview_to_virtual_slice_transform: transform a 3D point in overview image (in microns) to virtual slice (in microns)
        virtual_slice_to_overview_transform = \
            sitk.LandmarkBasedTransformInitializer( sitk.AffineTransform(2), flatten(fixed_landmarks), flatten(moving_landmarks) )
        overview_to_virtual_slice_transform = virtual_slice_to_overview_transform.GetInverse()

        # write out the overview_to_virtual_slice_transform
        file = os.path.join(working_directory,'overview_to_virtual_slice_transform.txt')
        sitk.WriteTransform( overview_to_virtual_slice_transform, file )

        # for m in pinning_info['markups']:
        #     print(m['name'], m['markup']['type'])

        # generate resampled overview image
        resampled_overview = \
            sitk.Resample(downsampled_overview, virtual_slice, virtual_slice_to_overview_transform, \
                        sitk.sitkLinear, 0, downsampled_overview.GetPixelID())

        # write the downsampled overview to file
        file = os.path.join(working_directory,'resampled_overview.nii.gz')
        sitk.WriteImage( resampled_overview, file, True ) 


        fig, axes = plt.subplots(nrows=1,ncols=3,figsize=(15,5)) 
        visualize_landmarks(downsampled_overview, axes[0], moving_landmarks)
        axes[0].set_title('20x with fiducials')
        visualize_landmarks( virtual_slice, axes[1], fixed_landmarks)
        axes[1].set_title('virtual slice with fiducials')
        visualize_landmarks( resampled_overview, axes[2], fixed_landmarks)
        axes[2].set_title('resampled 20x')
        plt.savefig(os.path.join(working_directory, 'transformation_overview.jpg'))
        # plt.show()
        plt.clf()


    except: 
        print('\tissue with this slice {}'.format(specimen_id))
        slices_with_issues[specimen_name] = 'issue with this slice'
        continue
# Out:
# Glt25d2-Cre_NF107;Ai14-570372.07.09
# spec: 1092058759
# Sst-IRES-Cre;Ai14-581875.06.04
# spec: 1111067076
# Sst-IRES-Cre;Ai14-594119.11.02
# spec: 1128233719
# spec: 1128216050
# spec: 1128211556
# Vip-IRES-Cre;Ai14-579327.08.04
# spec: 1105105529
# spec: 1105112071
# Vip-IRES-Cre;Ai14-585633.07.04
# spec: 1115415523
# Chat-IRES-Cre-neo;Ai14-600091.05.03
# spec: 1136795168
# spec: 1136784488
# spec: 1136762178
# spec: 1136724766
# spec: 1136743496
# Vip-IRES-Cre;Ai14-437116.02.01
# spec: 811699569
# spec: 810622500
# 	issue with this slice 810334213
# C57BL6J-588656.06.04
# spec: 1123293238
# Chat-IRES-Cre-neo;Ai14-564233.06.09
# spec: 1080362151
# spec: 1080371567
# Sst-IRES-Cre;Ai14-597074.09.02
# spec: 1133681776
# spec: 1133675234
# Chat-IRES-Cre-neo;Ai14-573899.03.10
# spec: 1097177576
# spec: 1097187808
# spec: 1097172863
# Chat-IRES-Cre-neo;Ai14-576497.03.03
# spec: 1099651737
# spec: 1099667477
# spec: 1099661552
# Sst-IRES-Cre;Ai14-552310.11.09
# spec: 1061496506
# spec: 1061522940
# spec: 1061508066
# Chat-IRES-Cre-neo;Ai14-576499.01.04
# spec: 1100133034
# spec: 1100117822
# spec: 1100106407
# Chat-IRES-Cre-neo;Ai14-576499.04.03
# spec: 1100119337
# spec: 1100092259
# C57BL6J-617127.16.09
# spec: 1159958157
# spec: 1159950270
# spec: 1159943288
# Chat-IRES-Cre-neo;Ai14-585475.07.03
# spec: 1115007040
# 	not enough fiducials
# Chat-IRES-Cre-neo;Ai14-627361.07.04
# spec: 1179674122
# spec: 1179663747
# spec: 1179650266
# Vip-IRES-Cre;Ai14-548766.08.06
# spec: 1056751512
# Chat-IRES-Cre-neo;Ai14-586529.06.04
# spec: 1116744057
# spec: 1116734143
# spec: 1116760087
# spec: 1116752365
# spec: 1116741154
# Esr2-IRES2-Cre;Ai14-557045.04.09
# spec: 1069261492
# 	issue with this slice 1069147202
# Gad2-IRES-Cre;Ai14-574194.04.10
# spec: 1098114638
# Nos1-CreERT2;Sst-IRES-FlpO;Ai65-553472.08.06
# spec: 1063288498
# spec: 1063317435
# Crh-IRES-Cre_ZJH;Sst-IRES-FlpO;Ai65-561244.07.05
# spec: 1075849371
# 	issue with this slice 1075814440
# Htr3a-Cre_NO152;Ai14-578482.07.03
# spec: 1103549779
# spec: 1103540661
# C:\Users\sarah.wallingbell\AppData\Local\Temp\ipykernel_16452\2978495204.py:159: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(nrows=1,ncols=3,figsize=(15,5))
# Sst-IRES-Cre;Ai14-554002.07.06
# spec: 1064669498
# Chat-IRES-Cre-neo;Ai14-600095.06.03
# spec: 1137881239
# spec: 1137872017
# spec: 1137831952
# Chat-IRES-Cre-neo;Ai14-600095.06.04
# spec: 1137881770
# spec: 1137869300
# spec: 1137857452
# spec: 1137849166
# spec: 1137839115
# spec: 1137831453
# Vip-IRES-Cre;Ai14-597353.09.01
# spec: 1132923582
# spec: 1132931432
# spec: 1132906901
# 	issue with this slice 1132314559
# Rorb-IRES2-Cre-neo;Ai14-571899.05.10
# spec: 1093670668
# spec: 1093665779
# Slc17a6-IRES-Cre;Ai14-578133.07.03
# spec: 1103819612
# spec: 1103808369
# spec: 1103814311
# Slc17a8-iCre;Slc32a1-IRES2-FlpO;Ai65-560685.08.06
# spec: 1074972057
# Sst-IRES-Cre;Ai14-601711.05.03
# spec: 1139884869
# spec: 1139874932
# Slc32a1-IRES-Cre;Ai14-562359.09.09
# spec: 1078105907
# spec: 1078119654
# Sst-IRES-Cre;Ai14-579950.09.03
# spec: 1107412447
# spec: 1107401239
# spec: 1107392867
# spec: 1107405539
# spec: 1107398612
# Sst-IRES-Cre;Ai14-572054.06.10
# spec: 1093219269
# spec: 1093227590
# C57BL6J-622939.08.04
# spec: 1171007170
# spec: 1171002224
# spec: 1170995444
# spec: 1170990380
# spec: 1170984664
# Chat-IRES-Cre-neo;Ai14-624495.09.03
# spec: 1174770186
# spec: 1174800265
# spec: 1174782099
# spec: 1174748328
# Chat-IRES-Cre-neo;Ai14-628761.08.03
# spec: 1181368509
# spec: 1181389327
# Pvalb-IRES-Cre;Ai14-621143.05.03
# spec: 1169005450
# spec: 1168997232
# spec: 1168991082
# 	issue with this slice 1168591826
# C57BL6J-618128.06.03
# spec: 1165641549
# spec: 1165631241
# spec: 1165616189
# spec: 1165601110
# Chat-IRES-Cre-neo;Ai14-623124.07.03
# spec: 1171523919
# spec: 1171516996
# spec: 1171500495
# C57BL6J-631344.08.04
# spec: 1186636247
# spec: 1186624336
# spec: 1186606441
# C57BL6J-631344.09.04
# spec: 1186658129
# spec: 1186646186
# spec: 1186631669
# spec: 1186622222
# spec: 1186607752
# Gad2-IRES-Cre;Ai14-600206.05.03
# spec: 1138783047
# spec: 1138748803
# Chat-IRES-Cre-neo;Ai14-627361.09.03
# spec: 1179704676
# spec: 1179678445
# spec: 1179663888
# spec: 1179650368
# spec: 1179642779
# C57BL6J-631344.06.03
# spec: 1186689965
# spec: 1186671271
# 	not enough fiducials
# C57BL6J-631345.08.03
# spec: 1186911393
# spec: 1186902243
# spec: 1186895968
# C57BL6J-631345.09.04
# spec: 1186919894
# spec: 1186908901
# C57BL6J-631343.08.04
# spec: 1187494453
# spec: 1187466832
# spec: 1187458888
# spec: 1187451110
# spec: 1187439658
# Sst-IRES-Cre;Ai14-572056.04.10
# spec: 1094658467
# spec: 1094649396
# spec: 1094653390
# Sst-IRES-Cre;Ai14-577302.07.04
# spec: 1102563731
# Htr3a-Cre_NO152;Ai14-622820.08.04
# spec: 1171742475
# spec: 1171733217
# Gad2-IRES-Cre;Ai14-574192.10.09
# spec: 1097648465
# spec: 1097686094
# Chat-IRES-Cre-neo;Ai14-624496.06.04
# spec: 1175042213
# spec: 1175037880
# spec: 1175009338
# Vip-IRES-Cre;Ai14-580199.07.02
# spec: 1107385194
# spec: 1107381086
# Chat-IRES-Cre-neo;Ai14-631355.13.04
# spec: 1186381788
# spec: 1186387872
# Vip-IRES-Cre;Ai14-579326.08.03
# spec: 1105548976
# spec: 1105533356
# spec: 1105523224
# C57BL6J-581851.08.03
# spec: 1108161845
# spec: 1108154695
# spec: 1108144727
# Chat-IRES-Cre-neo;Ai14-576499.02.04
# spec: 1100181806
# spec: 1100201749
# Vip-IRES-Cre;Ai14-579324.07.04
# spec: 1105851465
# spec: 1105877660
# spec: 1105858479
# spec: 1105870955
# Vip-IRES-Cre;Ai14-563145.10.09
# spec: 1078638507
# spec: 1078642825
# spec: 1078632197
# spec: 1078648226
# Esr2-IRES2-Cre;Ai14-557044.05.09
# spec: 1069022747
# spec: 1069014932
# spec: 1069006462
# 	issue with this slice 1068927614
# C57BL6J-581850.06.03
# spec: 1110119921
# spec: 1110128509
# spec: 1110141970
# spec: 1110136635
# spec: 1110114949
# Slc17a6-IRES-Cre;Ai14-564186.08.09
# spec: 1080333400
# 	issue with this slice 1080285500
# Gad2-IRES-Cre;Ai14-580680.07.04
# spec: 1107932448
# spec: 1107943926
# spec: 1107940275
# spec: 1107926759
# spec: 1107919996
# Sst-IRES-Cre;Ai14-586759.09.06
# spec: 1117172820
# spec: 1117164203
# 	issue with this slice 1116981016
# Vip-IRES-Cre;Ai14-579328.06.03
# spec: 1105265586
# spec: 1105279103
# spec: 1105270762
# spec: 1105258376
# Pvalb-IRES-Cre;Ai14-553660.05.06
# spec: 1064228044
# spec: 1064215621
# Slc17a6-IRES-Cre;Ai14-612219.07.04
# spec: 1153793721
# spec: 1153786207
# Htr3a-Cre_NO152;Ai14-563515.08.09
# spec: 1079059888
# spec: 1079052475
# Slc32a1-IRES-Cre;Ai14-562359.11.09
# spec: 1078083343
# Pvalb-IRES-Cre;Ai14-601230.11.01
# spec: 1138606423
# Vip-IRES-Cre;Ai14-579326.06.03
# spec: 1105548914
# spec: 1105563376
# spec: 1105527238
# Chat-IRES-Cre-neo;Ai14-585474.07.03
# spec: 1114201557
# spec: 1114176952
# Vip-IRES-Cre;Ai14-580792.05.04
# spec: 1110087339
# Ctgf-T2A-dgCre;Ai14-553529.08.06
# spec: 1063002851
# spec: 1062982792
# Chat-IRES-Cre-neo;Ai14-585474.07.04
# spec: 1114184642
# spec: 1114169471
# Vipr2-IRES2-Cre;Slc32a1-IRES2-FlpO;Ai65-562071.12.09
# spec: 1077512197
# spec: 1077497389
# spec: 1077492138
# spec: 1077505632
# Vip-IRES-Cre;Ai14-579327.06.03
# spec: 1105125008
# spec: 1105120258
# spec: 1105113624
# spec: 1105107361
# Vip-IRES-Cre;Ai14-614426.05.03
# spec: 1157114658
# spec: 1157101457
# C57BL6J-617129.15.09
# spec: 1162192211
# spec: 1162186692
# Sst-IRES-Cre;Ai14-577302.08.03
# spec: 1102597003
# Rbp4-Cre_KL100;Ai14-613769.06.04
# spec: 1155605484
# spec: 1155612022
# spec: 1155644981
# spec: 1155626106
# spec: 1155599881
# Rbp4-Cre_KL100;Ai14-618348.05.03
# spec: 1164138941
# Slc17a6-IRES-Cre;Ai14-622107.08.03
# spec: 1170225069
# spec: 1170241231
# spec: 1170231313
# spec: 1170220672
# Htr3a-Cre_NO152;Ai14-612284.05.04
# spec: 1153586259
# spec: 1153566411
# spec: 1153571464
# C57BL6J-618016.14.09
# spec: 1163207266
# spec: 1163201627
# C57BL6J-581849.07.03
# spec: 1110649251
# spec: 1110657782
# spec: 1110639701
# spec: 1110634455
# Chat-IRES-Cre-neo;Ai14-606033.04.04
# spec: 1145457847
# spec: 1145448011
# spec: 1145434936
# spec: 1145422781
# spec: 1145399888
# spec: 1145376882
# Gad2-IRES-Cre;Ai14-609670.07.03
# spec: 1150868114
# spec: 1150861217
# spec: 1150845443
# Htr3a-Cre_NO152;Ai14-609164.05.03
# spec: 1149758096
# spec: 1149754838
# Pvalb-IRES-Cre;Ai14-609902.08.03
# spec: 1150817664
# spec: 1150809230
# Pvalb-IRES-Cre;Ai14-621141.13.09
# spec: 1167595962
# spec: 1167594783
# spec: 1167589698
# spec: 1167585983
# spec: 1167581363
# Gad2-IRES-Cre;Ai14-609670.05.03
# spec: 1150862430
# spec: 1150858439
# spec: 1150850799
# spec: 1150846008
# spec: 1150840207
# Pvalb-IRES-Cre;Ai14-609903.07.04
# spec: 1151009636
# spec: 1151006031
# spec: 1150997837
# Vip-IRES-Cre;Ai14-614430.05.04
# spec: 1158423982
# spec: 1158452982
# spec: 1158436768
# Sst-IRES-Cre;Ai14-572053.04.10
# spec: 1092491103
# spec: 1092496785
# Sst-IRES-Cre;Ai14-577302.07.03
# spec: 1102579730
# spec: 1102565316
# Pvalb-IRES-Cre;Ai14-577972.06.03
# spec: 1104559882
# spec: 1104571935
# Rbp4-Cre_KL100;Ai14-618349.06.04
# spec: 1164176584
# spec: 1164166424
# spec: 1164160407
# Htr3a-Cre_NO152;Ai14-572779.04.10
# spec: 1095624234
# spec: 1095608757
# Vip-IRES-Cre;Ai14-579325.06.03
# spec: 1106085775
# Gad2-IRES-Cre;Ai14-600203.06.04
# spec: 1138252156
# spec: 1138261740
# spec: 1138256879
# spec: 1138247607
# Pvalb-IRES-Cre;Ai14-621142.14.09
# spec: 1167417713
# spec: 1167434054
# spec: 1167425389
# Htr3a-Cre_NO152;Ai14-621163.06.04
# spec: 1169273713
# spec: 1169253672
# spec: 1169226020
# spec: 1169219141
# spec: 1169212246
# Chat-IRES-Cre-neo;Ai14-623124.07.04
# spec: 1171515792
# spec: 1171505126
# spec: 1171498577
# Slc17a6-IRES-Cre;Ai14-564187.03.09
# spec: 1080563519
# spec: 1080580756
# Esr2-IRES2-Cre;Ai14-557045.05.09
# spec: 1069223587
# spec: 1069241269
# Chat-IRES-Cre-neo;Ai14-586528.05.04
# spec: 1115958163
# spec: 1115946836
# spec: 1115951976
# Rbp4-Cre_KL100;Ai14-618348.07.04
# spec: 1164142152
# spec: 1164128065
# Gad2-IRES-Cre;Ai14-600203.07.04
# spec: 1138258189
# spec: 1138334047
# spec: 1138315279
# spec: 1138293251
# spec: 1138266587
# spec: 1138245678
# C57BL6J-667556.08.06
# spec: 1258400492
# spec: 1258392243
# C57BL6J-631344.05.03
# spec: 1186681947
# C57BL6J-576333.08.04
# spec: 1101327251
# spec: 1101333398
# spec: 1101314002
# spec: 1101302999
# Vip-IRES-Cre;Ai14-618853.06.04
# spec: 1165895073
# spec: 1165878632
# Vip-IRES-Cre;Ai14-609322.06.04
# spec: 1150287637
# spec: 1150283763
# spec: 1150278979
# spec: 1150271816
# spec: 1150265225
# Vip-IRES-Cre;Ai14-609322.06.03
# spec: 1150288274
# spec: 1150281458
# spec: 1150271287
# spec: 1150265751
# Vip-IRES-Cre;Ai14-579327.07.04
# spec: 1105112668
# spec: 1105133139
# spec: 1105125716
# Slc17a6-IRES-Cre;Ai14-622106.07.03
# spec: 1170203488
# spec: 1170200533
# spec: 1170194461
# Slc17a7-IRES2-Cre;Ai14-564812.04.10
# spec: 1082283747
# spec: 1082287942
# Rbp4-Cre_KL100;Ai14-618349.05.04
# spec: 1164189294
# spec: 1164186195
# spec: 1164179948
# spec: 1164174136
# Vip-IRES-Cre;Ai14-579326.07.03
# spec: 1105547864
# spec: 1105534903
# Rorb-IRES2-Cre-neo;Ai14-611981.05.03
# spec: 1153538989
# spec: 1153536073
# Pvalb-IRES-Cre;Ai14-609302.05.04
# spec: 1150041139
# spec: 1150032813
# Slc17a6-IRES-Cre;Ai14-612219.07.03
# spec: 1153778278
# spec: 1153767044
# spec: 1153756548
# Rorb-IRES2-Cre-neo;Ai14-611981.07.03
# spec: 1153551115
# Pvalb-IRES-Cre;Ai14-609302.08.04
# spec: 1150062826
# spec: 1150045092
# spec: 1150038344
# Gad2-IRES-Cre;Ai14-600203.06.03
# spec: 1138245015
# spec: 1138241596
# C57BL6J-647683.06.04
# spec: 1217568425
# C57BL6J-622939.07.04
# spec: 1171007133
# spec: 1171000417
# C57BL6J-618127.06.03
# spec: 1165064555
# spec: 1165033046
# spec: 1165019480
# spec: 1165005356

# %%
slices_with_issues_df = pd.DataFrame.from_dict(slices_with_issues.items())
slices_with_issues_df.to_csv('slices_with_issues_20231031.csv', index=False)

# %% [markdown]
# Transform cell morphologies to CCF

# %%
# == To transform morphology file into CCF space
# 1) download the morphology from LIMS
# 2) if needed convert coordinates to micron - using the resolution of the 63x image
# 3) if needed correct for shrinkage - this should only affect the z coordinate! -swb add this for autotrace only cells
# 4) translate the (x,y) coorinates of the morphology such that the soma node is in the corresponding position in the overview image
# 5) transform the morphology to match the virtual slice
# ---- apply "overview_to_virtual_slice_transform" to the (x,y) coordinates of the morphology
# 6) transform from virtual slice to CCF space
# ---- apply "virtual_slice_to_ccf_transform" to the (x,y,z) coordinates of the morphology
# 7) transform back to PIR (CCF coords) from LPS (ITK coords) -swb
# 8) shift cell so soma is in pinned location in ccf (from json) -swb

# %% [markdown]
# Inputs

# %%
# cell_soma_path = get_cell_soma_coordinates()
# cell_soma_info = pd.read_csv(cell_soma_path)



# cell_soma_info = pd.read_csv(r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\lims_queries\cell_soma_structure_and_coords\cell_soma_information_20230621.csv')

# %%
# cells = pd.read_csv(r'\\allen\programs\celltypes\workgroups\mousecelltypes\SarahWB\ccf_slice_registration\fiducals.csv', encoding='windows-1252') #slides with fiducials

# %%
# somas = somas.merge(cells, how='inner', left_on='specimen_name', right_on='Specimen Name')

# %%
len(somas)
# Out:
# 2930

# %%
somas
# Out:
#       slide_specimen_id            specimen_name            x            y
# 0            1254192732  C57BL6J-667412.13.10.01  6725.000000  3807.984131  \
# 1            1254192732  C57BL6J-667412.13.10.02  6725.000000  3685.511719
# 2            1254192732  C57BL6J-667412.13.10.03  6725.000000  3607.036133
# 3            1189282403  C57BL6J-634112.05.01.01  8846.905344  1215.824000
# 4            1189282403  C57BL6J-634112.05.01.02  8698.307617  1624.090698
# ...                 ...                      ...          ...          ...
# 2925         1170367254  C57BL6J-622939.07.04.02  4331.213867  4061.798584
# 2926         1164113385  C57BL6J-618127.06.03.01  4275.000000  6365.933594
# 2927         1164113385  C57BL6J-618127.06.03.02  4275.000000  3978.592529
# 2928         1164113385  C57BL6J-618127.06.03.03  4275.000000  4124.779297
# 2929         1164113385  C57BL6J-618127.06.03.04  4275.000000  4512.876953
#
#                 z  structure_id structure_acronym
# 0     6180.958496           362                MD
# 1     6276.875000           362                MD
# 2     6302.043457           362                MD
# 3     2322.970703           821           VISp2/3
# 4     2576.191895           778             VISp5
# ...           ...           ...               ...
# 2925  6512.082520           672                CP
# 2926  4770.908691            56               ACB
# 2927  4848.456055           672                CP
# 2928  3536.724121           672                CP
# 2929  3494.421631           672                CP
#
# [2930 rows x 7 columns]

# %%
# somas = somas.query("specimen_name == 'Chat-IRES-Cre-neo;Ai14-585474.07.04.02'")
# somas

# %%
# name = 'C57BL6J-631344.08.04.01'
# cells = cells[cells['Specimen Name'] == name]
# cells

# %%
registered_cells = []
cells_with_issues = {}

for idx, cell in somas.iterrows():
    sp_name = cell['specimen_name']
    sl_name = sp_name.rsplit('.', 1)[0]

    print(sp_name)

    try:
        sp_id = get_id_by_name(sp_name)

        #check if there's a transform for this slice 
        slice_path = os.path.join(out, sl_name)
        if not os.path.isfile(os.path.join(slice_path, 'overview_to_virtual_slice_transform.txt')): continue #go on to next cell 
        if not os.path.isfile(os.path.join(slice_path, 'virtual_slice_to_ccf_transform.txt')): continue #go on to next cell 
        if not os.path.isfile(os.path.join(slice_path, 'alignment_output.csv')): continue #go on to next cell 


        #get soma loc in 20x 
        alignment_output = pd.read_csv(os.path.join(slice_path, 'alignment_output.csv'))
        this_cell_alignment = alignment_output[alignment_output.specimen_name == sp_name]
        if len(this_cell_alignment) != 1: 
            cells_with_issues[sp_name] = 'No soma pin'
            print('\t no soma pin')
            continue
        lims_soma = this_cell_alignment['center_micron'].values
        lims_soma = lims_soma[0][1:-2].split(' ')
        lims_soma = [float(i) for i in lims_soma if len(i) > 0]


        #make folder to save registered swcs
        swc_path = os.path.join(slice_path, 'SWC')
        if not os.path.exists(swc_path): os.mkdir(swc_path)


        #load affine transforms
        overview_to_virtual_slice_transform = sitk.ReadTransform(os.path.join(slice_path, 'overview_to_virtual_slice_transform.txt'))
        virtual_slice_to_ccf_transform = sitk.ReadTransform(os.path.join(slice_path, 'virtual_slice_to_ccf_transform.txt'))


        #register lims gold standard swc 
        try: 
            print('\tManual SWC:')
            swc_name = '{}'.format(sp_id)
            lims_path = list(get_swc_from_lims(str(sp_id)))[1]
            lims_path = edit_path(lims_path)
            morph = to_dict(lims_path)
            register_morph(sp_name, sp_id, lims_soma, morph, swc_path, swc_name, somas, 
                        overview_to_virtual_slice_transform, virtual_slice_to_ccf_transform)
            registered_cells = registered_cells + [sp_name+'_manual']
            print('\t\tMANUAL SWC REGISTERED!')
        except: print('\t\tno manual swc to register')

        #register autotrace raw swc
        try: 
            print('\tRaw autotrace SWC:')
            swc_name = '{}_autotrace_raw'.format(sp_id)
            raw_path = get_autotrace_raw_path(sp_id)
            # if os.path.isfile(raw_path):
            morph = to_dict(raw_path)
            morph = convert_pixel_to_um_dictnrn(morph, sp_id)
            register_morph(sp_name, sp_id, lims_soma, morph, swc_path, swc_name, somas, 
                    overview_to_virtual_slice_transform, virtual_slice_to_ccf_transform)
            registered_cells = registered_cells + [sp_name+'_raw']
            print('\t\tRAW AUTOTRACE SWC REGISTERED!')
            # else: print('\tno raw autotrace swc to register')
        except: print('\t\tno raw autotrace swc to register')

        #register autotrace pp14 swc
        try: 
            print('\tPost processed step 14 autotrace SWC:')
            swc_name = '{}_autotrace_pp14'.format(sp_id)
            pp14_path = get_autotrace_pp_path(sp_id, 14)
            # if os.path.isfile(pp14_path):
            morph = to_dict(pp14_path)
            morph = convert_pixel_to_um_dictnrn(morph, sp_id)
            register_morph(sp_name, sp_id, lims_soma, morph, swc_path, swc_name, somas, 
                    overview_to_virtual_slice_transform, virtual_slice_to_ccf_transform)
            registered_cells = registered_cells + [sp_name+'_pp14']
            print('\t\tPP14 AUTOTRACE SWC REGISTERED!')
            # else: print('\tno pp14 autotrace swc to register')
        except: print('\t\tno pp14 autotrace swc to register')

        
        #register autotrace pp22 swc
        try:
            print('\tPost processed step 22 autotrace SWC:')
            swc_name = '{}_autotrace_pp22'.format(sp_id)
            pp22_path = get_autotrace_pp_path(sp_id, 22)
            # if os.path.isfile(pp22_path):
            morph = to_dict(pp22_path)
            morph = convert_pixel_to_um_dictnrn(morph, sp_id)
            register_morph(sp_name, sp_id, lims_soma, morph, swc_path, swc_name, somas, 
                    overview_to_virtual_slice_transform, virtual_slice_to_ccf_transform)
            registered_cells = registered_cells + [sp_name+'_pp22']
            print('\t\tPP22 AUTOTRACE SWC REGISTERED!')
            # else: print('\tno pp22 autotrace swc to register')
        except: print('\t\tno pp22 autotrace swc to register')


    except: continue
# Out:
# C57BL6J-667412.13.10.01
# C57BL6J-667412.13.10.02
# C57BL6J-667412.13.10.03
# C57BL6J-634112.05.01.01
# C57BL6J-634112.05.01.02
# C57BL6J-634112.05.01.03
# Glt25d2-Cre_NF107;Ai14-570372.07.09.01
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# Sst-IRES-Cre;Ai14-581875.06.04.01
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# C57BL6J-634221.05.01.01
# Rbp4-Cre_KL100;Ai14-659000.10.06.02
# Rbp4-Cre_KL100;Ai14-659000.10.06.03
# Rbp4-Cre_KL100;Ai14-659000.10.06.04
# Pvalb-IRES-Cre;Ai14-593556.12.02.02
# C57BL6J-634222.04.01.01
# Sst-IRES-Cre;Ai14-594119.11.02.01
# 	Manual SWC:
# 		no manual swc to register
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# Sst-IRES-Cre;Ai14-594119.11.02.02
# 	Manual SWC:
# 		no manual swc to register
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# Sst-IRES-Cre;Ai14-594119.11.02.03
# 	Manual SWC:
# 		no manual swc to register
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# Rorb-IRES2-Cre-neo;Ai14-604947.14.02.01
# Pvalb-IRES-Cre;Ai14-593558.04.01.01
# Pvalb-IRES-Cre;Ai14-593558.04.01.02
# Pvalb-IRES-Cre;Ai14-593558.04.01.03
# Pvalb-IRES-Cre;Ai14-593558.04.01.04
# Pvalb-IRES-Cre;Ai14-593558.04.02.01
# Pvalb-IRES-Cre;Ai14-593558.04.02.02
# Pvalb-IRES-Cre;Ai14-593558.04.02.04
# Vip-IRES-Cre;Ai14-594741.14.02.01
# Vip-IRES-Cre;Ai14-594741.14.02.02
# Vip-IRES-Cre;Ai14-594741.14.02.03
# C57BL6J-625941.04.02.01
# Slc17a6-IRES-Cre;Ai14-634163.11.02.01
# Slc17a6-IRES-Cre;Ai14-634163.11.02.02
# Slc17a6-IRES-Cre;Ai14-634163.11.02.03
# Gad2-IRES-Cre;Ai14-626576.03.01.02
# Gad2-IRES-Cre;Ai14-626576.03.01.04
# Gad2-IRES-Cre;Ai14-626576.03.01.06
# Gad2-IRES-Cre;Ai14-626576.03.01.05
# Slc17a6-IRES-Cre;Ai14-606635.09.01.01
# Vip-IRES-Cre;Ai14-594743.11.02.01
# Vip-IRES-Cre;Ai14-594743.11.02.02
# C57BL6J-640170.12.02.02
# C57BL6J-640170.12.02.03
# C57BL6J-640170.12.02.04
# Vip-IRES-Cre;Ai14-579327.08.04.01
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
#
02
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# Pvalb-IRES-Cre;Ai14-609302.05.04.01
# 	 no soma pin
# Pvalb-IRES-Cre;Ai14-609302.05.04.02
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# Slc17a6-IRES-Cre;Ai14-612219.07.03.01
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		no pp14 autotrace swc to register
# 	Post processed step 22 autotrace SWC:
# 		no pp22 autotrace swc to register
# Slc17a6-IRES-Cre;Ai14-612219.07.03.02
# 	 no soma pin
# Slc17a6-IRES-Cre;Ai14-612219.07.03.03
# 	 no soma pin
# Rorb-IRES2-Cre-neo;Ai14-611981.07.03.01
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# Pvalb-IRES-Cre;Ai14-609302.08.04.01
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# Pvalb-IRES-Cre;Ai14-609302.08.04.02
# 	 no soma pin
# Pvalb-IRES-Cre;Ai14-609302.08.04.03
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# Gad2-IRES-Cre;Ai14-600203.06.03.01
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# Gad2-IRES-Cre;Ai14-600203.06.03.02
# 	Manual SWC:
# 		no manual swc to register
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP14 AUTOTRACE SWC REGISTERED!
# 	Post processed step 22 autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		PP22 AUTOTRACE SWC REGISTERED!
# C57BL6J-647683.06.04.01
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		no pp14 autotrace swc to register
# 	Post processed step 22 autotrace SWC:
# 		no pp22 autotrace swc to register
# C57BL6J-622939.07.04.01
# 	Manual SWC:
# 		no manual swc to register
# 	Raw autotrace SWC:
# 		no raw autotrace swc to register
# 	Post processed step 14 autotrace SWC:
# 		no pp14 autotrace swc to register
# 	Post processed step 22 autotrace SWC:
# 		no pp22 autotrace swc to register
# C57BL6J-622939.07.04.02
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		no pp14 autotrace swc to register
# 	Post processed step 22 autotrace SWC:
# 		no pp22 autotrace swc to register
# C57BL6J-618127.06.03.01
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		no pp14 autotrace swc to register
# 	Post processed step 22 autotrace SWC:
# 		no pp22 autotrace swc to register
# C57BL6J-618127.06.03.02
# 	 no soma pin
# C57BL6J-618127.06.03.03
# 	 no soma pin
# C57BL6J-618127.06.03.04
# 	Manual SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		MANUAL SWC REGISTERED!
# 	Raw autotrace SWC:
# 		Starting step 1
# 		Starting step 3
# 		Starting step 4
# 		Starting step 5
# 		Starting step 6
# 		Starting step 7
# 		Starting step 8
# 		Registration complete!
# 		RAW AUTOTRACE SWC REGISTERED!
# 	Post processed step 14 autotrace SWC:
# 		no pp14 autotrace swc to register
# 	Post processed step 22 autotrace SWC:
# 		no pp22 autotrace swc to register

# %%
cells_with_issues_df = pd.DataFrame.from_dict(list(cells_with_issues.items())) 
cells_with_issues_df.to_csv('cells_with_issues_20231031.csv', index=False)

# %%
registered_cells
# Out:
# ['Glt25d2-Cre_NF107;Ai14-570372.07.09.01_manual',
#  'Glt25d2-Cre_NF107;Ai14-570372.07.09.01_raw',
#  'Glt25d2-Cre_NF107;Ai14-570372.07.09.01_pp14',
#  'Glt25d2-Cre_NF107;Ai14-570372.07.09.01_pp22',
#  'Sst-IRES-Cre;Ai14-581875.06.04.01_manual',
#  'Sst-IRES-Cre;Ai14-581875.06.04.01_raw',
#  'Sst-IRES-Cre;Ai14-581875.06.04.01_pp14',
#  'Sst-IRES-Cre;Ai14-581875.06.04.01_pp22',
#  'Sst-IRES-Cre;Ai14-594119.11.02.01_raw',
#  'Sst-IRES-Cre;Ai14-594119.11.02.01_pp14',
#  'Sst-IRES-Cre;Ai14-594119.11.02.01_pp22',
#  'Sst-IRES-Cre;Ai14-594119.11.02.02_raw',
#  'Sst-IRES-Cre;Ai14-594119.11.02.02_pp14',
#  'Sst-IRES-Cre;Ai14-594119.11.02.02_pp22',
#  'Sst-IRES-Cre;Ai14-594119.11.02.03_raw',
#  'Sst-IRES-Cre;Ai14-594119.11.02.03_pp14',
#  'Sst-IRES-Cre;Ai14-594119.11.02.03_pp22',
#  'Vip-IRES-Cre;Ai14-579327.08.04.01_manual',
#  'Vip-IRES-Cre;Ai14-579327.08.04.01_raw',
#  'Vip-IRES-Cre;Ai14-579327.08.04.01_pp14',
#  'Vip-IRES-Cre;Ai14-579327.08.04.01_pp22',
#  'Vip-IRES-Cre;Ai14-585633.07.04.01_manual',
#  'Vip-IRES-Cre;Ai14-585633.07.04.01_raw',
#  'Vip-IRES-Cre;Ai14-585633.07.04.01_pp14',
#  'Vip-IRES-Cre;Ai14-585633.07.04.01_pp22',
#  'Chat-IRES-Cre-neo;Ai14-600091.05.03
#  'C57BL6J-581850.06.03.04_manual',
#  'C57BL6J-581850.06.03.04_raw',
#  'C57BL6J-581850.06.03.04_pp14',
#  'C57BL6J-581850.06.03.04_pp22',
#  'C57BL6J-581850.06.03.05_manual',
#  'C57BL6J-581850.06.03.05_raw',
#  'C57BL6J-581850.06.03.05_pp14',
#  'C57BL6J-581850.06.03.05_pp22',
#  'Gad2-IRES-Cre;Ai14-580680.07.04.03_manual',
#  'Gad2-IRES-Cre;Ai14-580680.07.04.03_raw',
#  'Gad2-IRES-Cre;Ai14-580680.07.04.03_pp14',
#  'Gad2-IRES-Cre;Ai14-580680.07.04.03_pp22',
#  'Slc32a1-IRES-Cre;Ai14-562359.09.09.01_manual',
#  'Slc32a1-IRES-Cre;Ai14-562359.09.09.01_raw',
#  'Slc32a1-IRES-Cre;Ai14-562359.09.09.01_pp14',
#  'Slc32a1-IRES-Cre;Ai14-562359.09.09.01_pp22',
#  'Ctgf-T2A-dgCre;Ai14-553529.08.06.02_manual',
#  'Ctgf-T2A-dgCre;Ai14-553529.08.06.02_pp14',
#  'Ctgf-T2A-dgCre;Ai14-553529.08.06.02_pp22',
#  'Vip-IRES-Cre;Ai14-579328.06.03.03_manual',
#  'Vip-IRES-Cre;Ai14-579328.06.03.03_raw',
#  'Vip-IRES-Cre;Ai14-579328.06.03.03_pp14',
#  'Vip-IRES-Cre;Ai14-579328.06.03.03_pp22',
#  'Vip-IRES-Cre;Ai14-579328.06.03.02_manual',
#  'Vip-IRES-Cre;Ai14-579328.06.03.02_raw',
#  'Vip-IRES-Cre;Ai14-579328.06.03.02_pp14',
#  'Vip-IRES-Cre;Ai14-579328.06.03.02_pp22',
#  'Pvalb-IRES-Cre;Ai14-553660.05.06.02_manual',
#  'Pvalb-IRES-Cre;Ai14-553660.05.06.02_raw',
#  'Pvalb-IRES-Cre;Ai14-553660.05.06.02_pp14',
#  'Pvalb-IRES-Cre;Ai14-553660.05.06.02_pp22',
#  'Slc17a6-IRES-Cre;Ai14-612219.07.04.01_manual',
#  'Slc17a6-IRES-Cre;Ai14-612219.07.04.01_raw',
#  'Slc17a6-IRES-Cre;Ai14-612219.07.04.01_pp14',
#  'Slc17a6-IRES-Cre;Ai14-612219.07.04.01_pp22',
#  'Slc17a6-IRES-Cre;Ai14-612219.07.04.02_manual',
#  'Slc17a6-IRES-Cre;Ai14-612219.07.04.02_raw',
#  'Slc17a6-IRES-Cre;Ai14-612219.07.04.02_pp14',
#  'Slc17a6-IRES-Cre;Ai14-612219.07.04.02_pp22',
#  'Htr3a-Cre_NO152;Ai14-563515.08.09.01_raw',
#  'Htr3a-Cre_NO152;Ai14-563515.08.09.01_pp14',
#  'Htr3a-Cre_NO152;Ai14-563515.08.09.01_pp22',
#  'Slc32a1-IRES-Cre;Ai14-562359.11.09.01_raw',
#  'Slc32a1-IRES-Cre;Ai14-562359.11.09.01_pp14',
#  'Slc32a1-IRES-Cre;Ai14-562359.11.09.01_pp22',
#  'Pvalb-IRES-Cre;Ai14-601230.11.01.01_manual',
#  'Pvalb-IRES-Cre;Ai14-601230.11.01.01_raw',
#  'Pvalb-IRES-Cre;Ai14-601230.11.01.01_pp14',
#  'Pvalb-IRES-Cre;Ai14-601230.11.01.01_pp22',
#  'Vip-IRES-Cre;Ai14-579326.06.03.01_manual',
#  'Vip-IRES-Cre;Ai14-579326.06.03.01_raw',
#  'Vip-IRES-Cre;Ai14-579326.06.03.01_pp14',
#  'Vip-IRES-Cre;Ai14-579326.06.03.01_pp22',
#  'Chat-IRES-Cre-neo;Ai14-585474.07.03.02_manual',
#  'Chat-IRES-Cre-neo;Ai14-585474.07.03.02_raw',
#  'Chat-IRES-Cre-neo;Ai14-585474.07.03.02_pp14',
#  'Chat-IRES-Cre-neo;Ai14-585474.07.03.02_pp22',
#  'Ctgf-T2A-dgCre;Ai14-553529.08.06.02_manual',
#  'Ctgf-T2A-dgCre;Ai14-553529.08.06.02_pp14',
#  'Ctgf-T2A-dgCre;Ai14-553529.08.06.02_pp22',
#  'Chat-IRES-Cre-neo;Ai14-585474.07.04.02_manual',
#  'Chat-IRES-Cre-neo;Ai14-585474.07.04.02_raw',
#  'Chat-IRES-Cre-neo;Ai14-585474.07.04.02_pp14',
#  'Chat-IRES-Cre-neo;Ai14-585474.07.04.02_pp22',
#  'Vipr2-IRES2-Cre;Slc32a1-IRES2-FlpO;Ai65-562071.12.09.03_manual',
#  'Vipr2-IRES2-Cre;Slc32a1-IRES2-FlpO;Ai65-562071.12.09.03_raw',
#  'Vip-IRES-Cre;Ai14-579327.06.03.04_manual',
#  'Vip-IRES-Cre;Ai14-579327.06.03.04_raw',
#  'Vip-IRES-Cre;Ai14-579327.06.03.04_pp14',
#  'Vip-IRES-Cre;Ai14-579327.06.03.04_pp22',
#  'Vip-IRES-Cre;Ai14-614426.05.03.01_manual',
#  'Vip-IRES-Cre;Ai14-614426.05.03.01_raw',
#  'Vip-IRES-Cre;Ai14-614426.05.03.01_pp14',
#  'Vip-IRES-Cre;Ai14-614426.05.03.01_pp22',
#  'C57BL6J-617129.15.09.02_manual',
#  'C57BL6J-617129.15.09.02_raw',
#  'Sst-IRES-Cre;Ai14-577302.08.03.01_manual',
#  'Sst-IRES-Cre;Ai14-577302.08.03.01_raw',
#  'Sst-IRES-Cre;Ai14-577302.08.03.01_pp14',
#  'Sst-IRES-Cre;Ai14-577302.08.03.01_pp22',
#  'Rbp4-Cre_KL100;Ai14-613769.06.04.03_manual',
#  'Rbp4-Cre_KL100;Ai14-613769.06.04.03_raw',
#  'Rbp4-Cre_KL100;Ai14-613769.06.04.03_pp14',
#  'Rbp4-Cre_KL100;Ai14-613769.06.04.03_pp22',
#  'Rbp4-Cre_KL100;Ai14-618348.05.03.01_manual',
#  'Rbp4-Cre_KL100;Ai14-618348.05.03.01_raw',
#  'Slc17a6-IRES-Cre;Ai14-622107.08.03.02_manual',
#  'Slc17a6-IRES-Cre;Ai14-622107.08.03.02_raw',
#  'Htr3a-Cre_NO152;Ai14-612284.05.04.01_manual',
#  'Htr3a-Cre_NO152;Ai14-612284.05.04.01_raw',
#  'Htr3a-Cre_NO152;Ai14-612284.05.04.01_pp14',
#  'Htr3a-Cre_NO152;Ai14-612284.05.04.01_pp22',
#  'C57BL6J-618016.14.09.02_manual',
#  'C57BL6J-618016.14.09.02_raw',
#  'C57BL6J-581849.07.03.02_manual',
#  'C57BL6J-581849.07.03.02_raw',
#  'C57BL6J-581849.07.03.02_pp14',
#  'C57BL6J-581849.07.03.02_pp22',
#  'C57BL6J-581849.07.03.03_manual',
#  'C57BL6J-581849.07.03.03_raw',
#  'C57BL6J-581849.07.03.03_pp14',
#  'C57BL6J-581849.07.03.03_pp22',
#  'C57BL6J-581849.07.03.04_manual',
#  'C57BL6J-581849.07.03.04_raw',
#  'C57BL6J-581849.07.03.04_pp14',
#  'C57BL6J-581849.07.03.04_pp22',
#  'Chat-IRES-Cre-neo;Ai14-606033.04.04.05_manual',
#  'Chat-IRES-Cre-neo;Ai14-606033.04.04.05_raw',
#  'Chat-IRES-Cre-neo;Ai14-606033.04.04.05_pp14',
#  'Chat-IRES-Cre-neo;Ai14-606033.04.04.05_pp22',
#  'Gad2-IRES-Cre;Ai14-609670.07.03.02_raw',
#  'Gad2-IRES-Cre;Ai14-609670.07.03.03_manual',
#  'Gad2-IRES-Cre;Ai14-609670.07.03.03_raw',
#  'Gad2-IRES-Cre;Ai14-609670.07.03.03_pp14',
#  'Gad2-IRES-Cre;Ai14-609670.07.03.03_pp22',
#  'Pvalb-IRES-Cre;Ai14-621142.14.09.01_manual',
#  'Pvalb-IRES-Cre;Ai14-621142.14.09.01_raw',
#  'Htr3a-Cre_NO152;Ai14-621163.06.04.04_manual',
#  'Htr3a-Cre_NO152;Ai14-621163.06.04.04_raw',
#  'Htr3a-Cre_NO152;Ai14-621163.06.04.05_raw',
#  'Chat-IRES-Cre-neo;Ai14-623124.07.04.03_raw',
#  'Slc17a6-IRES-Cre;Ai14-564187.03.09.02_manual',
#  'Slc17a6-IRES-Cre;Ai14-564187.03.09.02_raw',
#  'Slc17a6-IRES-Cre;Ai14-564187.03.09.02_pp14',
#  'Slc17a6-IRES-Cre;Ai14-564187.03.09.02_pp22',
#  'Esr2-IRES2-Cre;Ai14-557045.05.09.02_manual',
#  'Esr2-IRES2-Cre;Ai14-557045.05.09.02_raw',
#  'Esr2-IRES2-Cre;Ai14-557045.05.09.02_pp14',
#  'Esr2-IRES2-Cre;Ai14-557045.05.09.02_pp22',
#  'Chat-IRES-Cre-neo;Ai14-586528.05.04.01_manual',
#  'Chat-IRES-Cre-neo;Ai14-586528.05.04.01_raw',
#  'Chat-IRES-Cre-neo;Ai14-586528.05.04.01_pp14',
#  'Chat-IRES-Cre-neo;Ai14-586528.05.04.01_pp22',
#  'Rbp4-Cre_KL100;Ai14-618348.07.04.02_manual',
#  'Rbp4-Cre_KL100;Ai14-618348.07.04.02_raw',
#  'Gad2-IRES-Cre;Ai14-600203.07.04.06_manual',
#  'Gad2-IRES-Cre;Ai14-600203.07.04.06_raw',
#  'C57BL6J-667556.08.06.02_manual',
#  'C57BL6J-631344.05.03.01_manual',
#  'C57BL6J-631344.05.03.01_raw',
#  'C57BL6J-576333.08.04.04_manual',
#  'C57BL6J-576333.08.04.04_raw',
#  'C57BL6J-576333.08.04.04_pp14',
#  'C57BL6J-576333.08.04.04_pp22',
#  'C57BL6J-576333.08.04.03_raw',
#  'C57BL6J-576333.08.04.03_pp14',
#  'C57BL6J-576333.08.04.03_pp22',
#  'Vip-IRES-Cre;Ai14-618853.06.04.02_manual',
#  'Vip-IRES-Cre;Ai14-618853.06.04.02_raw',
#  'Vip-IRES-Cre;Ai14-609322.06.04.02_manual',
#  'Vip-IRES-Cre;Ai14-609322.06.04.02_raw',
#  'Vip-IRES-Cre;Ai14-609322.06.04.04_manual',
#  'Vip-IRES-Cre;Ai14-609322.06.04.04_raw',
#  'Vip-IRES-Cre;Ai14-609322.06.04.05_manual',
#  'Vip-IRES-Cre;Ai14-609322.06.04.05_raw',
#  'Vip-IRES-Cre;Ai14-609322.06.03.04_manual',
#  'Vip-IRES-Cre;Ai14-609322.06.03.04_raw',
#  'Vip-IRES-Cre;Ai14-609322.06.03.04_pp14',
#  'Vip-IRES-Cre;Ai14-609322.06.03.04_pp22',
#  'Vip-IRES-Cre;Ai14-579327.07.04.03_manual',
#  'Vip-IRES-Cre;Ai14-579327.07.04.03_raw',
#  'Vip-IRES-Cre;Ai14-579327.07.04.03_pp14',
#  'Vip-IRES-Cre;Ai14-579327.07.04.03_pp22',
#  'Slc17a6-IRES-Cre;Ai14-622106.07.03.01_manual',
#  'Slc17a6-IRES-Cre;Ai14-622106.07.03.01_raw',
#  'Slc17a7-IRES2-Cre;Ai14-564812.04.10.01_manual',
#  'Slc17a7-IRES2-Cre;Ai14-564812.04.10.01_raw',
#  'Slc17a7-IRES2-Cre;Ai14-564812.04.10.01_pp14',
#  'Slc17a7-IRES2-Cre;Ai14-564812.04.10.01_pp22',
#  'Rbp4-Cre_KL100;Ai14-618349.05.04.03_manual',
#  'Rbp4-Cre_KL100;Ai14-618349.05.04.03_raw',
#  'Vip-IRES-Cre;Ai14-579326.07.03.02_manual',
#  'Vip-IRES-Cre;Ai14-579326.07.03.02_raw',
#  'Vip-IRES-Cre;Ai14-579326.07.03.02_pp14',
#  'Vip-IRES-Cre;Ai14-579326.07.03.02_pp22',
#  'Rorb-IRES2-Cre-neo;Ai14-611981.05.03.02_manual',
#  'Rorb-IRES2-Cre-neo;Ai14-611981.05.03.02_raw',
#  'Rorb-IRES2-Cre-neo;Ai14-611981.05.03.02_pp14',
#  'Rorb-IRES2-Cre-neo;Ai14-611981.05.03.02_pp22',
#  'Pvalb-IRES-Cre;Ai14-609302.05.04.02_manual',
#  'Pvalb-IRES-Cre;Ai14-609302.05.04.02_raw',
#  'Pvalb-IRES-Cre;Ai14-609302.05.04.02_pp14',
#  'Pvalb-IRES-Cre;Ai14-609302.05.04.02_pp22',
#  'Slc17a6-IRES-Cre;Ai14-612219.07.03.01_manual',
#  'Slc17a6-IRES-Cre;Ai14-612219.07.03.01_raw',
#  'Rorb-IRES2-Cre-neo;Ai14-611981.07.03.01_manual',
#  'Rorb-IRES2-Cre-neo;Ai14-611981.07.03.01_raw',
#  'Rorb-IRES2-Cre-neo;Ai14-611981.07.03.01_pp14',
#  'Rorb-IRES2-Cre-neo;Ai14-611981.07.03.01_pp22',
#  'Pvalb-IRES-Cre;Ai14-609302.08.04.01_manual',
#  'Pvalb-IRES-Cre;Ai14-609302.08.04.01_raw',
#  'Pvalb-IRES-Cre;Ai14-609302.08.04.01_pp14',
#  'Pvalb-IRES-Cre;Ai14-609302.08.04.01_pp22',
#  'Pvalb-IRES-Cre;Ai14-609302.08.04.03_manual',
#  'Pvalb-IRES-Cre;Ai14-609302.08.04.03_raw',
#  'Pvalb-IRES-Cre;Ai14-609302.08.04.03_pp14',
#  'Pvalb-IRES-Cre;Ai14-609302.08.04.03_pp22',
#  'Gad2-IRES-Cre;Ai14-600203.06.03.01_manual',
#  'Gad2-IRES-Cre;Ai14-600203.06.03.01_raw',
#  'Gad2-IRES-Cre;Ai14-600203.06.03.01_pp14',
#  'Gad2-IRES-Cre;Ai14-600203.06.03.01_pp22',
#  'Gad2-IRES-Cre;Ai14-600203.06.03.02_raw',
#  'Gad2-IRES-Cre;Ai14-600203.06.03.02_pp14',
#  'Gad2-IRES-Cre;Ai14-600203.06.03.02_pp22',
#  'C57BL6J-647683.06.04.01_manual',
#  'C57BL6J-647683.06.04.01_raw',
#  'C57BL6J-622939.07.04.02_manual',
#  'C57BL6J-622939.07.04.02_raw',
#  'C57BL6J-618127.06.03.01_manual',
#  'C57BL6J-618127.06.03.01_raw',
#  'C57BL6J-618127.06.03.04_manual',
#  'C57BL6J-618127.06.03.04_raw']

# %%
registered_cells_df = pd.DataFrame(registered_cells)
registered_cells_df
# Out:
#                                                  0
# 0    Glt25d2-Cre_NF107;Ai14-570372.07.09.01_manual
# 1       Glt25d2-Cre_NF107;Ai14-570372.07.09.01_raw
# 2      Glt25d2-Cre_NF107;Ai14-570372.07.09.01_pp14
# 3      Glt25d2-Cre_NF107;Ai14-570372.07.09.01_pp22
# 4         Sst-IRES-Cre;Ai14-581875.06.04.01_manual
# ..                                             ...
# 459                    C57BL6J-622939.07.04.02_raw
# 460                 C57BL6J-618127.06.03.01_manual
# 461                    C57BL6J-618127.06.03.01_raw
# 462                 C57BL6J-618127.06.03.04_manual
# 463                    C57BL6J-618127.06.03.04_raw
#
# [464 rows x 1 columns]

# %%
registered_cells_df.to_csv('registered_cells_20231031.csv', index=False)
